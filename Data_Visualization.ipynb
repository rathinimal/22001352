# %%
install.packages("ggplot2")
# Out:
# Installing package into ‘/home/nimal/R/x86_64-pc-linux-gnu-library/4.3’
# (as ‘lib’ is unspecified)

# %%
library(ggplot2)

# %%
ggplot(mtcars, aes(x = wt, y = mpg)) + geom_point()
# Out:
# plot without title
